# %% [markdown]
# <a href="https://colab.research.google.com/github/jrmesquita7/Statistics-for-Data-Science/blob/notebooks-initial/Statistics_Library_in_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import yfinance as yf # API yahoo finanças

# %%
ticker = yf.Ticker('ITUB4.SA')
data = ticker.history(period='1y')
data
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2023-10-17 00:00:00-03:00  25.759760  25.806425  25.386430  25.498428
# 2023-10-18 00:00:00-03:00  25.265098  25.470431  24.835770  24.966434
# 2023-10-19 00:00:00-03:00  24.901101  25.573095  24.807769  25.255764
# 2023-10-20 00:00:00-03:00  25.125100  25.414430  24.957101  25.162432
# 2023-10-23 00:00:00-03:00  25.106434  25.489097  25.031768  25.190434
# ...                              ...        ...        ...        ...
# 2024-10-11 00:00:00-03:00  34.830002  34.970001  34.549999  34.630001
# 2024-10-14 00:00:00-03:00  34.740002  35.070000  34.619999  34.849998
# 2024-10-15 00:00:00-03:00  34.900002  35.310001  34.730000  35.250000
# 2024-10-16 00:00:00-03:00  35.250000  35.270000  34.849998  35.040001
# 2024-10-17 00:00:00-03:00  34.689999  35.430000  34.540001  35.180000
#
#                              Volume  Dividends  Stock Splits
# Date
# ...

# %% [markdown]
# Filtrar dados em uma df

# %%
df2 = df2.filter(items=['Open', 'Close'])
df2
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
df2 = data.filter(like='gh', axis=1)
df2
# Out:
#                                 High
# Date
# 2023-10-17 00:00:00-03:00  25.806425
# 2023-10-18 00:00:00-03:00  25.470431
# 2023-10-19 00:00:00-03:00  25.573095
# 2023-10-20 00:00:00-03:00  25.414430
# 2023-10-23 00:00:00-03:00  25.489097
# ...                              ...
# 2024-10-11 00:00:00-03:00  34.970001
# 2024-10-14 00:00:00-03:00  35.070000
# 2024-10-15 00:00:00-03:00  35.310001
# 2024-10-16 00:00:00-03:00  35.270000
# 2024-10-17 00:00:00-03:00  35.430000
#
# [253 rows x 1 columns]

# %% [markdown]
# Escolher colunas

# %%
df = data['Close']
df
# Out:
# Date
# 2023-10-17 00:00:00-03:00    25.498428
# 2023-10-18 00:00:00-03:00    24.966434
# 2023-10-19 00:00:00-03:00    25.255764
# 2023-10-20 00:00:00-03:00    25.162432
# 2023-10-23 00:00:00-03:00    25.190434
#                                ...
# 2024-10-11 00:00:00-03:00    34.630001
# 2024-10-14 00:00:00-03:00    34.849998
# 2024-10-15 00:00:00-03:00    35.250000
# 2024-10-16 00:00:00-03:00    35.040001
# 2024-10-17 00:00:00-03:00    35.180000
# Name: Close, Length: 253, dtype: float64

# %%
df = data[['Close', 'Open']]
df
# Out:
#                                Close       Open
# Date
# 2023-10-17 00:00:00-03:00  25.498428  25.759760
# 2023-10-18 00:00:00-03:00  24.966434  25.265098
# 2023-10-19 00:00:00-03:00  25.255764  24.901101
# 2023-10-20 00:00:00-03:00  25.162432  25.125100
# 2023-10-23 00:00:00-03:00  25.190434  25.106434
# ...                              ...        ...
# 2024-10-11 00:00:00-03:00  34.630001  34.830002
# 2024-10-14 00:00:00-03:00  34.849998  34.740002
# 2024-10-15 00:00:00-03:00  35.250000  34.900002
# 2024-10-16 00:00:00-03:00  35.040001  35.250000
# 2024-10-17 00:00:00-03:00  35.180000  34.689999
#
# [253 rows x 2 columns]

# %% [markdown]
# Retirar linhas

# %%
df = data.drop(['2024-10-16', '2024-10-17'], axis=0) # axis = 0 linhas
df
# Out:
#                                 Open       High        Low      Close  \
# Date
# 
0.0
#
#                            Stock Splits  new_dividends
# Date
# 2023-10-17 00:00:00-03:00           0.0            2.0
# ...

# %%
df['new_dividends'] = df['Dividends'].map({0:5.00}).where(data.index == '2024-10-17') # criando uma coluna com outros valores com condições
df
# Out:
#                                 Open      Close    Volume  Dividends  \
# Date
# 2023-10-17 00:00:00-03:00  25.759760  25.498428  26816300        0.0
# 2023-10-18 00:00:00-03:00  25.265098  24.966434  55863000        0.0
# 2023-10-19 00:00:00-03:00  24.901101  25.255764  23164800        0.0
# 2023-10-20 00:00:00-03:00  25.125100  25.162432  23846300        0.0
# 2023-10-23 00:00:00-03:00  25.106434  25.190434  16052700        0.0
# ...                              ...        ...       ...        ...
# 2024-10-11 00:00:00-03:00  34.830002  34.630001  16968500        0.0
# 2024-10-14 00:00:00-03:00  34.740002  34.849998  14436100        0.0
# 2024-10-15 00:00:00-03:00  34.900002  35.250000  28801300        0.0
# 2024-10-16 00:00:00-03:00  35.250000  35.040001  34988700        0.0
# 2024-10-17 00:00:00-03:00  34.689999  35.180000  13438100        0.0
#
#                            Stock Splits  new_dividends
# Date
# 2023-10-17 00:00:00-03:00           0.0            NaN
# ...

# %%
bove = pd.read_csv('/content/bovespa1998-2019.csv')
bove
# Out:
#         TIPREG      DATPRG  CODBDI   CODNEG  TPMERC        NOMRES  ESPECI  \
# 0            1  1998-01-02      96    PAL 3      20    PAUL F LUZ    ON *
# 1            1  1998-01-02      62    CMI 4      30          CMIG  PN *EJ
# 2            1  1998-01-02      62    PET 3      30          PETR    ON *
# 3            1  1998-01-02      62    SHA 4      30          SHAP    PN *
# 4            1  1998-01-02      62    TEL 4      30          TELB    PN *
# ...        ...         ...     ...      ...     ...           ...     ...
# 330627       1  2000-08-15       2    PLDN4      10     POLIALDEN    PN *
# 330628       1  2000-08-15      96  PETR4FF      20     PETROBRAS      PN
# 330629       1  2000-08-15      78  TSPPL31      70          TSPP    PN *
# 330630       1  2000-08-15      96  CALI4FF      20  CONST A LIND    PN *
# 330631       1  2000-08-15      78   PLIMJ7      70          PLIM      PN
#
#         PRAZOT MODREF  PREABE  ...  TOTNEG     QUATOT     VOLTOT  PREEXE  \
# ...

# %%
bove = bove[bove['CODNEG'] == 'PETR4']
bove
# Out:
#         TIPREG      DATPRG  CODBDI CODNEG  TPMERC     NOMRES ESPECI  PRAZOT  \
# 19326        1  1998-03-16       2  PETR4      10  PETROBRAS   PN *     NaN
# 19745        1  1998-03-17       2  PETR4      10  PETROBRAS   PN *     NaN
# 20259        1  1998-03-18       2  PETR4      10  PETROBRAS   PN *     NaN
# 20790        1  1998-03-19       2  PETR4      10  PETROBRAS   PN *     NaN
# 21172        1  1998-03-20       2  PETR4      10  PETROBRAS   PN *     NaN
# ...        ...         ...     ...    ...     ...        ...    ...     ...
# 327676       1  2000-08-08       2  PETR4      10  PETROBRAS     PN     NaN
# 327873       1  2000-08-09       2  PETR4      10  PETROBRAS     PN     NaN
# 328497       1  2000-08-10       2  PETR4      10  PETROBRAS     PN     NaN
# 329227       1  2000-08-11       2  PETR4      10  PETROBRAS     PN     NaN
# 329795       1  2000-08-14       2  PETR4      10  PETROBRAS     PN     NaN
#
# ...

# %%
bove['NOMRES'] = bove['NOMRES'].replace('PETROBRAS', 'PETROBRAS.SA')
bove
